# %%
import pandas as pd
from youtube_transcript_api import YouTubeTranscriptApi

# %%
ytt_api = YouTubeTranscriptApi()

# %%
ytt_api.fetch(video_id='7zr3A4g4x5c', languages=['en','vi'])
# Out:
# FetchedTranscript(snippets=[FetchedTranscriptSnippet(text='Xin chào và chào ừng bạn đã trở lại với', start=0.16, duration=4.44), FetchedTranscriptSnippet(text='phân tích game đã gần một tháng kể từ', start=2.32, duration=4.16), FetchedTranscriptSnippet(text='lần cuối mình ra video về nội dung phân', start=4.6, duration=3.68), FetchedTranscriptSnippet(text='tích game đó là video phân tích popy', start=6.48, duration=3.64), FetchedTranscriptSnippet(text='play tham chapter 4 và cảm ơn tất cả các', start=8.28, duration=4.239), FetchedTranscriptSnippet(text='bạn vì sự ủng hộ của video đó Tháng hai', start=10.12, duration=4.04), FetchedTranscriptSnippet(text='vừa rồi thật sự là một khoảng thời gian', start=12.519, duration=4.76), FetchedTranscriptSnippet(text='thú vị đầu tháng chúng ta có ccd 2 cuối', start=14.16, duration=5.44), FetchedTranscriptSnippet(text='tháng chúng ta có Monster the Wi và Đó', start=17.279, duration=4.041), FetchedTranscriptSnippet(text='cũng là hai trò chơi mà mình
# ...

# %%
df = pd.read_parquet(r"C:\Users\caotr\Downloads\sponsorTimes.parquet")

df.head()
# Out:
# C:\Users\caotr\AppData\Local\Temp\ipykernel_5236\2438589158.py:1: DtypeWarning: Columns (18,19) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r"C:\Users\caotr\Downloads\sponsorTimes.csv")
#        videoID  startTime    endTime  votes  locked  incorrectVotes  \
# 0  1rb3bMvDdX4  588.94100  631.89777    159       0               1
# 1  fBxtS9BpVWs   41.00000   53.00000    115       0               1
# 2  9P6rdqiybaw  488.52150  542.11035     -2       0               1
# 3  ulCdoCfw-bY  487.50198  547.48750     -2       0               1
# 4  uqKGREZs6-w  475.52167  532.20874    302       0               1
#
#                                    UUID                                userID  \
# 0  28aff450-a372-11e9-b256-cb886cabe693  38e7c2af-09f4-4492-bf49-75e443962ccd
# 1  b2465943-1313-449c-b75c-08b14756ac0a  38e7c2af-09f4-4492-bf49-75e443962ccd
# 2  81024780-a367-11e9-b256-cb886cabe693  38e7c2af-09f4-4492-bf49-75e443962ccd
# ...

# %%
df[df['videoID'] == '1rb3bMvDdX4']
# Out:
#              videoID  startTime     endTime  votes  locked  incorrectVotes  \
# 0        1rb3bMvDdX4  588.94100  631.897770    159       0               1
# 7        1rb3bMvDdX4    0.00000    6.861597    350       0               1
# 42502    1rb3bMvDdX4    0.00000    7.000000    -24       0               1
# 231927   1rb3bMvDdX4  633.01636  636.101000      2       0               1
# 392520   1rb3bMvDdX4    0.00000    6.700895      0       0               1
# 2394984  1rb3bMvDdX4  630.92096  636.101000      0       0               1
#
#                                                       UUID  \
# 0                     28aff450-a372-11e9-b256-cb886cabe693
# 7                     28ab1250-a372-11e9-b256-cb886cabe693
# 42502    2860f2403ae5b872ca95480ff72dec8f77744d597afefe...
# 231927   767eb5e07b2c08df12ae2c64bb0a1251bd3281a9f0412b...
# 392520   046204e6d7d14d31c936e9fc69c8b989cab537fbd45a9f...
# 2394984  572df20ca1110af5fae1117ab8e493c810a0656729f43e...
#
# ...

# %%
df.to_parquet(r'C:\Users\caotr\Downloads\sponsorTimes.parquet')
